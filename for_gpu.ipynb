# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 64 # how many independent sequences will we process in parallel?
block_size = 256 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 500
learning_rate = 3e-4
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
eval_iters = 200
n_layer=6
n_head=6
dropout=0.2 # used to randomly drop some neurons during training to not make the model depend on only one neuron basically used to prevent overfitting
n_embd=384  # the vector which gives meaning to each token
# ------------

torch.manual_seed(1337)

# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']: # for each split
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# this is a self attetion block
class Head(nn.Module):
    def __init__(self,head_size):
        super().__init__()
        self.key=nn.Linear(n_embd,head_size,bias=False)  #What information does it have
        self.query=nn.Linear(n_embd,head_size,bias=False) #What is the token looking for
        self.value=nn.Linear(n_embd,head_size,bias=False) #What should the token share
        self.register_buffer('tril',torch.tril(torch.ones(block_size,block_size)))
        self.dropout=nn.Dropout(dropout)

    def forward(self,x):
        B,T,C=x.shape
        k=self.key(x)
        q=self.query(x)
        #compute attention scores(affinities)
        wei = q @ k.transpose(-2, -1) * (k.size(-1) ** -0.5)
        wei=wei.masked_fill(self.tril[:T,:T]==0,float('-inf'))
        wei=F.softmax(wei,dim=-1)
        wei=self.dropout(wei)
        #weighted aggregation (the mean of the previous tokens and the present token)
        v=self.value(x)
        out=wei @ v
        return out

class MultiHeadAttention(nn.Module):

    def __init__(self,num_head,head_size):
        super().__init__()
        self.heads=nn.ModuleList([Head(head_size) for _ in range(num_head)])
        self.proj=nn.Linear(head_size * num_head,n_embd)  # this step is used for optimisation
        self.dropout=nn.Dropout(dropout)  # used to randomly drop some neurons during training to not make the model depend on only one neuron

    def forward(self,x):  # x is the addition of the pos_emb and tok_emb
        out=torch.cat([h(x) for h in self.heads],dim=-1)
        out=self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):

    def __init__(self,n_embd):
        super().__init__()
        self.net=nn.Sequential(
            nn.Linear(n_embd,4*n_embd), # this is used to refine the own values of n_embd and give rise to a stronger learned network of n_embd
            nn.ReLU(),
            nn.Linear(4*n_embd,n_embd),  # the * 4 is used as a optimization technique to allow the model to learn more complex representations it was given imn the official documentation of the attention is all you need documentation
            nn.Dropout(dropout) # used to randomly drop some neurons during training to not make the model depend on only one neuron
        )
    def forward(self,x):
        return self.net(x)

class Block(nn.Module):  # this is used to run the multi head attention and feed forward network again to gain further understanding of the tokens by the model and improve the performance

    def __init__(self,n_embd,n_head):
         super().__init__()
         head_size=n_embd//n_head
         self.sa=MultiHeadAttention(n_head,head_size)
         self.ffwd=FeedForward(n_embd)
         self.ln1=nn.LayerNorm(n_embd)
         self.ln2=nn.LayerNorm(n_embd) # mean and variance are taken to normalise it so we take n_embd and based on it we normalise the layers and the data

    def forward(self,x):
        x= x+ self.sa(self.ln1(x))
        x= x + self.ffwd(self.ln2(x))
        return x


# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)   # converts the vocab_size each token to a vector space of length n_embd to help the model know the importance of that specific word in the data
        self.position_embedding_table=nn.Embedding(block_size,n_embd)
            # changes the vector back to the vocab_size token to display the token
        # self.blocks=nn.Sequential(
        #     Block(n_embd,n_head=4),
        #     Block(n_embd,n_head=4),
        #     Block(n_embd,n_head=4),
        #     nn.LayerNorm(n_embd)
        # ) # the below line is same as this but prettier
        self.blocks=nn.Sequential(*[Block(n_embd,n_head=n_head) for _ in range(n_layer)])
        self.lm_head=nn.Linear(n_embd,vocab_size)
        # self.sa_head=MultiHeadAttention(4,n_embd//4)  # 4 is the no of multiheads that is looking at the tokens
        # self.ffwd=FeedForward(n_embd)
        # we initialised these 2 above lines in Block class so we dont need it here
        self.lnf=nn.LayerNorm(n_embd) # this is the finalNorm and it is used to normalise the output of the model until now and make the data clean

    def forward(self, idx, targets=None):
        B,T=idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb=self.token_embedding_table(idx)  # the tokens that are embedded into n_embd space vector (B,T,n_embd)
        pos_emb=self.position_embedding_table(torch.arange(T,device=device))
        x=tok_emb+pos_emb
        #x=self.sa_head(x)  # this is the multi head attention block and passing the value to it
        #x=self.ffwd(x)  # after finding the attention of the token in the data and how it corresponds and the position of the token to other tokens we then use feed forward to further improve the model by learning from the patterns fo the multi head attention block and further improve the weight and quality of the value
        # the above lines are replaced by the line below due to the Block class running these even better
        x=self.blocks(x)
        # after the above x runs it returns messy data because of the continous computation of the blocks and layers so we use the below line to normalise it and make it clean
        x=self.lnf(x)
        logits = self.lm_head(x) # (B,T,C)   #it converts the vector into tokens (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # cropping the content of idx to match the size of batch_size
            # when generating text, the model works on batches in parallel for each batch, at every step, it looks only at the last block_size tokens using this
            idx_crop=idx[:,-block_size:] # this crop the length of block_size from the last and pass them to the forward layer and then find thier position embedding and token_embedding of those characters it
            # get the predictions
            logits, loss = self(idx_crop)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=500)[0].tolist()))
# Out:
# cuda
# --2026-01-17 15:34:38--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.03s
#
# 2026-01-17 15:34:38 (32.6 MB/s) - ‘input.txt’ saved [1115394/1115394]
#
# step 0: train loss 4.2846, val loss 4.2820
# step 500: train loss 1.8865, val loss 2.0022
# step 1000: train loss 1.5361, val loss 1.7221
# step 1500: train loss 1.3952, val loss 1.6038
# step 2000: train loss 1.3081, val loss 1.5497
# step 2500: train loss 1.2525, val loss 1.5164
# step 3000: train loss 1.2010, val loss 1.4919
# step 3500: train loss 1.1589, val loss 1.4809
# step 4000: train loss 1.1225, val loss 1.4788
# step 4500: train loss 1.0845, val loss 1.4730
#
# But with price of this nightity-night
# Shakes unstrumpet shall compell'd flood at their hand:
# Commend our match'd true in Rome; and there
# Come on:
# The marshal, go, take up thee, whose loss asleep: I hear
# I lie a turn of right; serve the world to pardons
# Without the oweigh'st odd, it is a my son'st!
#
# CORIOLANUS:
# It is against this in London and spice,
# My wars shall be men that loved them.
#
# SICINIUS:
# Go, I will company: leave your counsels in
# The heaven their prison voices which they muld stug,
# Whi

# %%
print(decode(m.generate(context, max_new_tokens=5000)[0].tolist()))
# Out:
# I are moccupation: yet mock you go
# I; let the insuicent.
#
# Clown:
# Neither been, enough.
#
# ANGELO:
# The truth, he has says day 'scapell'd:
# There in thy housessadings of heaven, my warm's friend,
# When thou darest neck fur leant-speaking already:
# And when Thomas seem to mean a most,
# As I say well in happy deed.
# Now, very weapony, for them!
#
# KING RICHARD II:
# Have and turitute's own truth, again,
# And as pomix mortalst Rash at such a course,
# As it were here in her sweet smelted the earth,
# To weeping on Earrer their with wrongs and hearts their name
# Nearth-heems. Hear me, go I slain;
# So what make, for short shall be signs rerabs?
#
# ROMEO:
# Beside this is mista betted
# That; my poor commisses ratter this.
# ROMEO:
# They say, behold liberty havy leggers day.
#
# BENVOLIO:
# They let me there we carred again;
# I, not Romeo with with thy life rage,
# And yet late mistress as I do not believed,
# My good could be reprous condition,
# From by and ask me with transfold'sterations,
# Is suck for a whoremastion as hob
# To greater. Clevo, fortune, let the hair to love.
#
# BIONDELO:
# What, man, what belies it be, Then is it sweet. Fare it is not Clifford,
# To hither and more things will contrare.
#
# DUCHESS OF YORK:
# And every man,
# As that may be they no more come to you;
# Now they good not on hatrid them,
# Slilly shall well reep the rude of the complain.
# Let us this trial marry of us, at your father's self.
#
# DUKE OF YORK:
# And that mayors have I left it to coll form
# With the emplote sea place, for where
# And then ye, with us morning and no wear,
# Cuts with his new by that honour is of mine.
# I, give me for he in purpose: what desperay?
#
# GLOUCESTER:
# He comes thee seems by the chorsenty tall.
#
# LADY ANNE:
# I will not I keep that head to occass where he bed:
# I tell thee, if you are old,
# As for me is no feddering was and made grow,
# Upon my favour heartens of command.
# Speak those he was the shadopt to midest stay.
#
# First Lord:
# That's thy blest, let Romeo with him: and the
# cools unly and good no gentle send in a Volscian
# made or rage that stand to mak?
#
# Provost:
# By heavy him, strolling: so.
#
# ABCA:
# I do not how the king glad-mord nor close:
# My liege Romeo, ho, hearing youth, the lieved tRome
# In chairs you, tilts, and I have now the air
# More than can a heart their form than; you, lords.
# Both Great Lord Angelo, thou hadst him succease;
# Who is all prock'd my lay in their well;
# As grold's come with the white with frown discorate.
# By the greate-solvers shall be our wall and iron
# The heads of Marcius growry pound. His body days
# It spake, gentleman: he will ask the certain
# It is hot for. But has power that would at light he
# Wicked the supple fearing of a child, stated,
# Hoping stop and sustify hours into their dumbs,
# And barring fortune! for thee will not try blest,
# Your trinking and moes with thee: ay, and be too unwell,
# And must conteor me to your full arms;
# He will not be secured with our eart.'
# Their mirth I metal of a beggoment.
#
# FROTH:
# Your vown dudgman:
# O quickly tell him, she cried, that dead heart-like
# That death imprise their explace prisons.
# If we have with this lies and lively news.
#
# CAPULET:
# Now, you hear the metal re of death; somethinks,
# That living mess'd son cries with us: he, there here,
# In charged the thwick-learences, are I may
# Tell you you for her better members murder wrong.
#
# Nurse:
# My master's Jove, be gone.
#
# JULIET:
# Hence, when you oft grieve me that of the acts.
#
# ROMEO:
# And I, should who fund theels Barnardine.
#
# JULIET:
# I do beseech it so see, my lord.
#
# ROMEO:
# She is a thoughtnom liest?
#
# JULIET:
# Not be held.
#
# Nurse:
# Indeed, traitors, makes you our flamity
# Is trides, in the queen army thief;
# Should the succeed in the crown of your brother state.
#
# NORTHUMBERLE:
# No your expects with wrong.
#
# KING RICHARD III:
# Nor not Garden had rather werved!
#
# CATESBY:
# We do not so; why come to murderer us,
# I am conceal us to to see 't 'em.'
# They fail, and lay me so.
# Go, good stand on, my lord;
# Do I though my heart imprectide me,
# And save the ground mountain thy hand:
# The correction mistress confessor low:
# The parliking of itself blood isdeed my words,
# The master by Duke of Westmissa standingly.
# Thou goe'st the execution.
#
# QUEEN MARGARET:
# This seals my lost father's graciously steen;
# And march by necessly hath becomed cours;
# They have cry next revenge of them are may wench
# The hate.
#
# CLARENBUCH:
# Why with my Lad-Son? there is the least?
#
# KING HENRY VI:
# Banished master Gloucester, grace the colour.
# Thus, softly did make my court?
#
# Second Keeper:
# Having Gentleman, if very house, I will thy next,
# They not spend to Rome hear hich to us:
# I can grace thy hearth a direful wedged strack
# To glaster, freed Romeo!
#
# COMINIUS:
# Well, well!
# I know not what he is a deadly woful knave.
#
# CORIOLANUS:
# Else? and half the Tewksbury; open his hate
# Your friends creder's Rutland of County's death,
# His love to come the same one hath gone:
# Troophers of breath, told Norfolk at fight!
#
# VOLUMNIA:
# Say so, to pleasing.
# I shall begin to-morrow: how doth you good lucks;
# For I'ld rough a please many very so

# %%
print(decode(m.generate(context, max_new_tokens=50000)[0].tolist()))
# Out:
# Thou shalt hide it in his highness, for hearts
# Wedge to his high him: heretance had he spoken till he shunles
# Against the foreheads full of the rest.
#
# LORD FITZWill not to light, I forget this fit.
#
# WARWICtme I commod. How de I hither,
# This fortune of the prince. France  slaves awot
# Lest his son in the humour strives of high
# And made thee galience found, as so mortally
# From the faree deadly flooders' seas,
# Occounting to do I at the deep him!
# Therefore was the right to the love amber!
# Will you purgar to report them that be a-wearAge;
# Alone to singer why heads the moonshy stage,
# And let's their soul on a beauty year,
# Which we repose out of the roverenous
# But like one words. Be in the kill'd not to adds,
# All the man lose cens fires.
#
# SICINIUS:
# Thou brave the more horse eyes fair from fear!
#
# MENENIUS:
# It will make thee, no more: for all wont thee
# Than Mercutio to bed!
# O Trualts, pointy, I have currentle for squeen.
#
# BRAKE OV:
# Be recover, movey'd the fight; I lot my dreadful Clarence,
#
# Sold Somerse:
# Though they for the coats not a grafted in me
# devourity, a word of those postant hearts mock
# Show their weigh fingers  our hearts.
#
# CLIFFORD:
# Cobscare have you come to the mortal of the late.
#
# HENRY BOLINGBROKE:
#
# WARWICK:
# Your prodise Larrel! How farewell; who manside you well,
# Your posterous with move your England man begar
# I can rich battle, for her to us,
# Were thy legs will be dream'd to the crown.
# And I have so gloveful writes have, be ourselves,
# I laid many the greetest for me.
# What!c Valer hath not hour business me batter?
# No, are to seldom the joints, your mistrets in
# The power that suffer the bove slave.
#
# Second Murderer:
# This way, they not deliver this worthipby. Fourth, in that
# I was a play, there by that many; but let myself,
# Your noble York.
# No toe Moret!--O God O,--God, if I
# Will such pride,
# Whom for our beries wal best, as to honour time
# Are no more, if you know the cockatroy
# With us rotten: you yest a me leaves;
# Which, your offend you are too day, the answering
# Ver: if it did see the leat, have I deny tedious
# With him shed odds, and plack'd, I may renown'd;
# And live is service.
#
# Servant:
# Be your shallows set no Antigonuro,
# The strike straughter, high command tender,
# Where have somethin taste as a man peace.
# Better you a minute, but warm you.
#
# AUFIDIUS:
# And has he done, so: I much with him.
#
# ARCHIDAMUS:
# All so who prompts you, leaves sweet from his grave,
# We knew may merry that time action, the world
# I charge within her drown with a word: till may be in his doubted
# A place complicly! Hall'd mercy our wives,
# They stand his roins arms will too. There lies
# Farewing his son by posper of his vice,
# And the soul re uglories of death
# and the ear made of my soul vows in his head;
# Nay so 't my blind blows and grieves so dead
# Of slavish-vantas.
#
# YORK:
# Tut, a gentle-appear on that you owe ever your gwory.
#
# YORK:
# Then I uncle appointed to know; his causeful now
# See him terms there to hell me to our knows,
# Which his heart was wrew awaked:
# By general court
# I should with my sweet marries; what say 'brother'?'
# Came, my lord, we must say alread--'O, that advice
# With ever lieutenanced with way I set thee from fall
# And there at, the shades of law did by owe.
# Come, every no!
#
# GLOUCESTER:
# Why, who Bagain was import death?
#
# KING EDWARD IV:
# Ay, we musted meetars to dust, O:
# Why, tell where fellows, fathers' are walls by ourselves.
#
# FRALIET:
# As we are heard him so much;
# But straw the king with indeed and speed;
# Come, there's nothing Henry they seized.
#
# GLOUCESTER:
# 'Tis you, Sir Lord Hastings, Hre Lard Froker Horter,
# And Opposeth his lent,
# To piece of it deserving from his colours.
#
# KING EDWARD IV:
# And throw the princess stretch, and love him from out
# To greedy, as we will strike be the crown.
#
# LORD FITZWATER:
# How now, my father, adieu! althought,
# Which you owe swear what yourself no due,
# Grae all the tears of peace with Marcius doth.
# What you will our Large?
#
# LADY GREY:
# Sweet I then, I forget will call thee sporth is Capulet.
#
# BUCKINGHAM:
# Upon sweet some proceedite cut off, let alone.
#
# KING RICHARD III:
# No caught thee two him with a tlaw;
# For opprection lie's moderary and comes
# Ears to do him soon as hite to me.
# O, what would he do wert it on, might to have:
# The time still other hard was, never curse. O, yet
# The statue of being between stirr'd.
# If thy story note our hand defect thy shadow:
# Ahow we beat to coming thy wife. if we our pawn,
# Fast our well crim in the troops of traitor,
# Did live an old follow to well!
#
# LEONTES:
# At the rage, after honour, both he ther mag
# And swelling trim no deserve of his;
# Bless long from our poisons. How now, have let us been!
# 3 KING HENRY VI
#
# KING HENRY VI:
# We wilt prince to-day?
#
# KING HENRY VI:
# Though part please will stand by the right of thee.
#
# QUEEN MARGARET:
# And by what too name?
#
# KING HENRY VI:
# Troy, my prophet, look'd? what then?
#
# Second KING HENRY VI:
# O mayor, sovereign, I cannot great her.
#
# First Watcutan:
# For this arm the sought-faced her send,
# And quickly handled from his traotgue sup,
# Or Halp doth seize of this speeding late,--
# I would speak, she hath boding to drunk again.
#
# Third Waton set the die unto the King of Richard!
# Werewith thou the children blood the haughts.
#
# DORSET:
# 'Twas done make, do I trusty Plass's dispose.
#
# HENRY BOLINGBROKE:
# Thou well call the losting to forget:
# This is he wish'd your bloody that hath morning of.
# Farewell me, that he were be doget.
#
# KING EDWARD IV:
# Why, stay, geest the Dolphos, loving of the earth,
# Then callain my hroud kisself, their head
# Sha$ls, and that having a break the had head
# That will unslaughter'd men ob their farments,
# Those words with barns must stiff and stain:
# Put marries apparents, batter wour hearts,
# My breader trembling in my truth!
#
# ERCUTIO:
# Come Amulan fifts his black she was as Brittanding that
# friended Ludly ape: and no stand in thee.
#
# HERMIONE:
# Have patricate!
#
# JULIET:
# How my brother, what children?
#
# DUKE VINCENTIO:
# The corsons and go subject!
# My soul answers are less in lawful swords,
# Braving than we shall the heart becomes with root
# As with the rag, is to to my them?
# Or ill-be a person from the right, being order,
# That high wanting when they do look down,
# Their native shall kest ence with others
# And to me every ever now.
# Lord Aufidine, for thy tribe way
# With for tongue strong clips, we making Fres;
# For twinul enterive to what thy love of ug:
# O, thou, make up her story,
# My hearts, and do the enemy's army is,
# Be pluked men night, and gripe and chosety,
# And stick in happy how the would short slaughters,
# Acceptages im as hand; which true the game,
# I see his deep: on thy soul's wife image,
# With thereto tenders deadly thee brave up and weeds
# Are they  dead! rours! Come revenge not Angelo.
#
# DORCAS:
# I do him not, fast and give Mercutio ghostle gate.
# Was never his of war,
# As my parts of files will be seeme myself frames.
# Come, for your babes: but him plays there quarters
# Upon makes! how thou dodst goes, do so
# Twenty again, like a tenay traitor stor!
# I take a traitor, I must spake and the
# my paintant from us; with Temples who lates
# Shall speak between are the debless on peace.
# We are quencal too post the heart of cur us,
# With deputy with heaven the rest of;
# A right sleeping for Edward and make up hymal steel,
# Seems us, to unjoy gave us pomfreth,
# In safform these parts in pablants.
# Hark you mistake not my dreadful:
# So corrumise, you will not our child,--
# As I will have a-griped is not hold comfort.
# I can, as I do tell it so?
#
# NORTHUMBERLAND:
# Alas, ar speak no pointed; and, now no issue:
# The Lord of Edward to Henry is choosener
# By father's wife, and doth rest, at Saint Palant Baptis
# How now, Dor Warwick's in France?
# My sovereign free him of your greece, loger!
#
# NORTHUMBERLAND:
# No rescue, on 'scape!' Away God's king,
# What mop of si great liers, as most that thou art
# now a poot. I was to mine: now, I charitors an us.
#
# Messenger:
# Bid them not me, depute:
# They are revenge more to fall in presents with all,
# Yea, and so, lest you'll and so say them by
# Their twenty, their heads and corns to pite;
# I reverently, in no more sentence
# The holds of the reasury of their purposes. Your bloody execute
# Unvirenced, and your honour willings;
# The faints be pass, to I did light sleep your in right;
# The dead not delivers' eye, linger yets;
# your high parch's trial agains
# At I had breed him knowly be gone.
#
# KING RICHARD II:
# What stand still would come 'tnot hold him?
#
# FRIAR THOBAS:
# That should in my father: friends are my fear'd
# With himself, gaunt his sight and maken boy:
# Unmetiding meant be thy daughter darkness.
# Far is he the god: the liest Mombary.
# Here, brother, sirrah, go; to knock him from Angelo:
# He unto grieve him.
#
# BRUTUS:
# Here comes this misportake any holl!
# Honour!
#
# Second Capulet:
# Thieve governments and even will draw outd,
# If your sweet shall be consider.
#
# Second Citizen:
# Here closes here, and you can it would
# Open your spile madam with the hand. Let now:
# Sint so, so my most, as I full open
# mortal my city hearts!
# Go, hound unshallow; I do not, kill my daughter'd,
# No separate to be acholy flag:
# Come, go with not point means, for time to look it,
# Bugs not back more with death.
#
# DOWS:
# Which secret how light take yourself?
#
# MONTAGUE:
# The promption and the Lord of Sicilia,
# Whom I kind by return thee, that perfect am Edward
# Who from their here step to thee, ere I thy walls
# Had he heart swerved that brought of bowect.
# The green being Henry's daughter, I fear thee, let not
# Or 'twere thine adverse serves of both,
# Bestrided our son; and, ports are unfold.'
# Thus is hell-hearted. And in the prayer fair heed.
# Thy sweet train more than two shoulders,
# Takes, slaught poerlance one are grew murders,
# Be by coat death-filed dischanted, by the blood
# Fies of house that subject His honour. Thee, that mayorself
# A bid sorrow of his love enterman in them.
# Having you dotardy toggarment deposers me this death.
# Gethreat Herald, with a pardon blame speedy small wear,
# As he lived better than to do my grave,
# Unless live: indeed, any garbered wills.
#
# YORK:
# Grandfold, gently!
#
# BUCKINGHAM:
# Witch art thy fear of Friar own fair ladys' last
# Thou dishonour'd of his hands, take his nature
# Upon his intends; relike floving him,
# Hath grim the his mind of war, fair drial
# To our mortal, precise and trembles, should poport
# 'Find using to his plactiple:' Why, she, he re is dead!
#
# JULIET:
# But is acconding, Clarence with anneck;
# Be coursed in England from Rome
# Call and Oxford Stanley's blanchelor like of false.
# Is the tewerving of a God?
# O prison! O wretchedress, a day!
# Look of faithful I reposed her from you:
# Or your talms the south, I for't your kin:
# I am a country's to priest a sleeping:
# Made you shall be fearful some words,
# Go play with Angelo grieve had beard,
# There are done of grief. If you know'st, how our sheetest, what
# You have fortune's of your father.
# Come on, you blames me heaven, farewell.
# Can! lends we can he be stake: we have periswed this
# pragree will come to his Tranks
# With murder friendship her eyes: mother livery,
# To happy them whence he were no shape.
# Does Glory, thou hunt of my silence co-quealt,
# And stir Flures drop Garet's fdon speak well in helm!
# And saycrown some roses, lough no more that kill'd
# Atteres his blood. Those unpeers pours are his head,
# Makes him a sair for Jetua's time.
# Yet well not Green him: in my day is the wind:
# Shrew made him dreams living leaves,
# So overs he louds cheers Claudebrights and child:
# 'Tis his well-shall'd your intents,
# Now stridely soulsh through temptain to it.
#
# NORTHUMBERLAND:
# Hark! Hark's herd! and here's his pothecard
# The Duke of GORIO:
# If to hear his success. Seize on't;
# The which, while you have now I have been's,
# And not slew his offict friendly, he loves,
# Will she smoke, hour sister, would then she will do,
# Write is, for his soul asurer's deam.
# I hath not come a thing to his buzzen
# Should censure an enement a love:
# Ay could be't a tapp'd betwixts the fall of death!
# Thinks we would all thy hunder, let him peace.
#
# SICINIUS:
# Erraw what mean of the warlike that we have
# That way to perceed in thee: anchors, gracion
# That made ne'er something there, threat our coats to give the skarquen.
# Our subjects are glouds of good that Tranibles?
#
# Servant:
# Now Romeo, Lord Bocket, mayor and Northambert.
#
# HERMIONE:
# Unless; for my heart-clamorous here;
# I will fight thee all with distriples,
# And the Henry of York, or I is far parce.
#
# GREEN:
# When I grow March-disposed will not no more good?
#
# KING HENRY VI:
# Woe may be blest
# To come the tidings of Tite contrary.
# Then cheer these magsance here urged
# Marm'd thread from your freeer nail wars.
#
# KING RICHARD III:
# That Clifford, whose threagon your princes?
# You can will unI accustom trouble:
# Return me: alas the world keep yond to be pluck'd
# A friend wife are rapeligent. Hand!
# Hence is Elbow, mark! make the mattor,
# This lands from get him for your knife: we for his met,
# He shadow, some not common bring them, where
# Or that with him!
# You'll stay what dost, but twent to--Lo exple
# For arms night me, see was a partion for a codly gard,
#
# EDWARD:
# And wake in himself of his prosperous slaves;
# But thought, ere they love shall be urgal in his city.
# Upon him, I must loves hed to know his good?
#
# CLARENCE:
# You like Sicilian, well accommand:
# Were hold tnought you go; merceive you there,
# I will plague to my growing Romeo, that I should.
#
# SLY:
# I have percept: their wife was being join'd,
# Could fier from ere uncertain my very
# pardonage that well return in his greaty.
#
# ROMEO:
# We have blemish'd for you our self, survice
# Of men some perforciders.
# Here is the people of his contrary,
# Making shave men our heads there
# With heaven our evil rooping toward him;
# And this powerful master is his name;
# Hill plucked, with deserves, but shed by his honours
# Are into many hots: he hath so shall
# A serpous of teem at good affoic say:
# Within, heart Marcius speak.
# Come hence, leaves you me, go, here come;
# His buckle to make him such a treason less:
# Bid his new sposs'd the words encount pest.
# Why, that, marchiaf, at march, and ma more!
#
# JULIET:
# Ay, she's a noble feed.
#
# LADY CAPULET:
# I'll teach your hands.
#
# QUEEN EL:
# KING Harry, she's jotely.
#
# DORSET:
# Threw king and tears for me, If doth him come:
# Thou hast of the Tower I should commany,
# When I further from my daughter fight, their generate,
# And much friends, George you to the house.
#
# QUEEN ELIZABETH:
# Consent thou shalt thy defactor, my Lord Hastings;
# For thou of it is stopp'd, on thy bears?
# How we troibled my forth? why the madam's being?
#
# QUEEN ELIZABETH:
# O, what doth is receive, lord? look up the mouse
# Unvising than a hind, an in our grift watch'd,
# In whose bandishonours' braughters' writ,
# I am labour on it.
# Be a bolt thou codest.
#
# KING RICHARD II:
# What may governmently and unpiece;
# For God's sharp-vallar, laid to deep leave!
#
# Justice:
# Wilt thou do but have, but that I to ssy to thee,
# That sever 'twas thou wouldst have scivent again.
#
# QUEEN ELIZABETH:
# How now, my Lord of York both:
# 'Tis mondary, how I have heard thee to speak;
# I will become to Rome, with my present Georget,
# Or fair here in the fault of my knight.
#
# QUEEN MARGARET:
# Peace, foul, sir, early Plantagenet,
# With all obstain Ditors,
# Nake Gaunt grants near England on France:
# Master LuXENES:
# Be quiet me, as thou art all thee garland,
# So is true thee our kins. See how my father late,
# Her true like sister, I waid,
# The sufficter woe in the place, resist of a way
# Whose might jod! Thursday I dare the hearth.
#
# Provost:
# Most arm, I friar, cousin, to prove me such with a
# fixed and termits of any behavior hate which her
# dulls, shall him again: he hard terry him to the
# peace one of Lancontage, ere he furnafful king,
# Ravely as Titus joy.
#
# KING RICHARD II:
# I that, Clarence, fellow'st thou wilt; for Edward's power:
# Tarr'd for his face some gentlewomen's life,
# True inquire or my protethries' sake,
# And black, taking the day of night
# Be cornted again forgiven us approach:
# I'll rens
# The prime 'twas not mortal to knavoury;
# For stood so ever said his father good of Camillo.
#
# KING RICHARD II:
# Camillo, you shall be gone to the truth.
#
# FRIAR LAURENCE:
#
# KING RICHARD III:
# Greater, speak, you much kill yours.
# You may pay your patience, gladder to-morrow.
# I called your grace; O well is souch dedarly;
# If no doubt--cound'st nothing sining was sweet.
#
# TYRREL:
# And must petty trespects at hear and men:
# No; might you, ladies, and have some othe
# As if appects and pity: it fight.
#
# CLARENCE:
# As London, I say the Lord Angelo,
# I'll be my terms sorript in my heed all,
# As I'll poenty Plantagenet.
#
# KING EDWARD IV:
#
# CLAUD OF YORK:
# Why, who come to this great like is a joy:
# Because I respect my tongue have an opent;
# You shall who needs not your stars and wo guld.
#
# DION:
# In should the queen to deflay heaven, do speak upon
# Their fiends of horns; till it spoke condition:
# What's your flours, your grace comes honesty,
# Attem used, a dresecond rob of it,
# A magrity, for that humbles, and bids you,
# Upon me from the flowers thards did refusal me,
# That his power to devotion.
#
# KING RICHARD II:
# Now wilt thou melt me hence. Yet I did there be tell.
#
# CATESBY:
#
# KING RICHARD III:
# 'Twere trike Gloucester, at now brook up,
# Having more strumpete thee for our wish.
#
# Shepherd:
# On all mercy, abody more was from than angels
# To be recomptation of any ording:
# I would prove a kind bowl, here in request,
# Whill, farmer be to spend by me to these wrect words.
# They to kept the slander that, now impregnibal,
# His thought I will acconted my mother,
# Methough you thither he tents will declie me.
# He make no my humour friend, whose ample wild not I?
# Now towards God, that he hath raid his house wonder.
# Doth the expected him, and lose the vaults of the
# Tyrror others in his trailor.
#
# GREY:
# My lords, amen, at you thus!
# Well all you are excelN'd penetives the
# flies, Paris: where re I did speak it mine own
# Common worship in Exeter'd and I.
#
# LEONTES:
# Then Clifford, with Montague.
#
# Lord:
# Uncle, lord.
#
# LEONTES:
# By alcounteous lands,
# But who back downright the folk of destroy's right.
# The god-greatest crept; of putting spill,
# Where is child the affection.
#
# AUFIUS:
# Such is the treasonable three sir,
# The value and length.
#
# GLOUCESTER:
# Ay, but why think you that, To suspect you.
#
# COMINIUS:
# O, the word you give 't:
# Master wherein the Capulet, of
# This good manner-ro like such a bab: accord,
# I'll make us ease you, sir, its, tedive you?
# Tree fast your voices slaves.
#
# GREEN:
# Say you it will these the more being down,--
# Whose contradverse, digesteth so your queen,
# As you will strive, who are beats to him:
# For art though you shall conspines, and poke
# On them contrar touch'd threat your liberty.
#
# LEONTES:
# Your words;
# On whom had to o'er-worrow the king
# That foul shall be shut they show love not down:
# I could bot say, that is not my bount; but, I have
# I actor'd in Desmisses rebusiness for thee.
# Of foe, let's have let me spend my husband.
#
# BENVOLIO:
# Here's the matter. Come on,
# He durst not soon: Pleaseth him but by
# The lip, and best my Lady signs.
#
# MONTAGUE:
#
# CAPULET:
# O mine one in The sea of great, I'll feel yet: now it.
# Put boy, be condemned, pray: I have past thuc nature.
# His cousin soften: specially pardon, sitness, as hands
# off such as man's trifes well wrinkling from me:
# And sleeping this father's right hath about
# Her own, were to king, and appeares for our foe
# The ear of and precties? I preserve a few,
# Still you might take from the principh:
# A brack of power-faced, cals you the father.
#
# GLOUCESTER:
# O, badded you, and fled in with slave!
# Will the living sue of it?
#
# HENRY PERCY:
# Farewell, lie, come to you, standing Plantagenet.
#
# GLOUCESTER:
# I know not what I do tell my father will give;
# Thou had ere I show thee soft slain to-day.
#
# KING EDWARD IV:
# An if all-hand say strike it be my king,
# No such as at mingly rice:
# Look'd idly that with thy life; and I do part,
# The strivix drew shall make me no lose;
# What was within, mights for what was, thou hast respect.
# I knock in present to your duty:
# This is, and shall fear your extremity
# Hereby to follow our fortunes, starn'd heaven kiss,
# Send of your shieldred aged himself shorring.
# Look a most on! O, let Bolingbroke, spy back
# Be you the while begg'd broken in rest yords.
#
# WARWICK:
# Edward, how we does long land, and Henrife of Wales,,
# They shall hard you what uncleanting for Neels?
# Mercy, and I do well live, leave the flinty sleep,
# To dream in love of a termsmanqueror hearts;
# And teal us strike no royal took a humble,
# Making discles, not that fall'd them with inha
# My hearth, he could but drink his east. See how his sword a
# new what arm is youth'd in patrick? I would you go a
# forged himself.
# I say, Assay  my lords: but we have learn them all
# 'Remembers of the power. Heaven me, my soul opposider,
# and I mispatch'd to him, of I splight bade
# For our father'd with himself the earld,
# I have to mark her he is please.
#
# AUFIDIUS:
# As I will decallate me still: let's the stip
# Art thou hast weep forth.
#
# AUFIDIUS:
# O word thou hast done?
# Who rot Against come more to marriers thou hast marr'd;
# Your graft, be haved, not so much to to a hole!
# His lady'st offenced many. As thou art conful
# To is it, he would lay a man broken, if he together;
# Our fellow is be so up,
# That quickly in things will bowdling throw,
# He mights come to hide think will not perforce.
# What, let me on joy?
# Harry, wheres a cause that I kneel be with slept you;
# Clafform to my majesty
# Let live that my tongue that have perEship,
# So 'twere to be so limit at hands him in tears.
# And he heard were the regal prince, or go what a
# thirst he cannot to find his English friend,
# Strength had teach unto me frowrit for Londona
# In him justice of his bed, do breath his oad,
# and guilty strength not for the kervill's death.
# For Romeom hither:
# Heaven lek the puttars, cannot from a marvel.
# Why should have letter his priest subjectly book!
# Either'd his with much redemption with her hearts,
# He last the hearted of summon friar.
#
# KING RICHARD II:
# I would you did feath his presently
# Scounselves night he is doth know.
#
# All:
# For strike me here, I'ld be in the town.
#
# STANLEY:
# How thy news, Boy?
#
# QUEEN MARCHIO:
# Nay I return:
# This good Polixtent, the restion,
# Foul shake, the bloody may vexalue; the city flat--
# As it like captiving to me thrift my joy:
# Then should enough it seal no plucks his oath from
# Cannot by thut.
#
# LUCENTIO:
# Silen Meantime; give me the ripents speak more with thee.
#
# CLAUDIO:
# Ho! full apply; for the self-loving trear, blood
# Will we pray in to flats arm ever with sha.
#
# ISABELLA:
# Therefore this farther, on my fife,
# I will stand was look'd with a smile our counce.
#
# DUKE VINCENTIO:
# Call it Claudio is my lad,
# Or to such a prophesy.
#
# ISABELY:
# O Buckingham, cook, stick you had them all the
# Where he drivines me to speak with or bears; sile have valourer,
# My hought friends mine will obscurry cours.
#
# DUKE VINCENTIO:
# It are the great on his worthy, like a devils
# From you: blasts, of the heart, affrighted of the
# notice of mortal, their approarety,
# I send your walls, than so defend their friends: himselves
# if they comes not violent tell. For thou scorns tend
# still upon him.
# His time he had, if thou cravest it off?
# Or none let my treath, do I plead my weapons;
# That play when he shall will draw theirs not: they are say,
# I wail ite nobleness; but notious bawd.
#
# POLIXENES:
# So plague that your rights will them going?
#
# CAMILLO:
# Howles do them know me against the ground.
# Swear wast the sword that spow from all,
# But witch marshal with the king from Criest,
# And brough of feed in pherjory. Her Abhorson,
# Here down for his moist noble were the reason.
# I promptorm, get thee wretch it is breast before:
# By Gremiting this tooth your hatress make me for the
# vey harm.
#
# ARCHIDAMUS:
# In: there, sir, unright; but what!
#
# Clown:
# Pardone!
#
# First CoPETER:
# Go along.
#
# Nurse:
# Go, thinken; for our wonders: you must he have.
#
# Second Murderer:
# Marshal; be cockle: how thy place all feel,
# Hailstly of all daughter: poor good night, he's
# signs enemies, not have denute him of thee:
# now he, and that I will but his battle; serve
# thought out his fellow or fires and sin blush'd, and his:
# There shall the bold blow there is dead.
#
# CLARENCE:
# A go, turn of a king!
#
# CLARENCE:
#
# BARNCA:
# O Mon, alnobard's in chair witchcraft,
# He children hast not thou canst not straight the suckers,
# More than thou whet were about the lay,
# That west the far off, where from the petty stales,
# That hours are to standers, lack speed with feast;
# Tears she now some startice, are our powers' strange;
# Bolely and wides as bloody upon their writes,
# Against them, bleathed in femals at Clifford,
# Is Desperately her lightness to grant them tyral.
#
# JULIET:
# Is encounted it was hither for tyranny?
#
# DUKE VINCENTIO:
# I know thee?
#
# RIVERS:
# O, well no like his wife: you, sir;
# My horses find, for how I do lief that the word.
#
# DUKE OF YORK:
# No bloody Clarence! for have I subject.
#
# HENRY BOLINGS:
# I thought imprison it long a gambling diread;
# I then reason like an how them.
# See, methoughts we here sleep'd before thee stirs?
# Thou for thy royal tongue; I'll be gone.
# Say not an oath, no look, make son, what you?
#
# Fitzwatcomen:
# God hath power that I had to it it;
# And by thy love on thy sight, to do chamber.
#
# KING RICHARD II:
# Where have? you can these twe went so;
# Through we are dun'er speechled in his hand,
# Upon him and would not revenge the dub,
# Beneathed upon their princess! O both what hath's sound
# By strange these true and let it sit it die:
# The dustful till I remedy that you ships.
#
# RICHARD:
# The mother queen's bosom, she is now; was she
# Ovenom o'er the other Clarence before by death,
# I durst love out not spread to them.
#
# CATESBY:
# I do it like than she operial,
# At Angelo. 'Tis ever Milla.
#
# KING RICHARD III:
# There I straight there, fully arms.
# Upon thee, we have seen thee who, so for this
# With regound Rutlady trial.
# Near Barnardine, we have lay'd in gentleman,
# Before heaving both the garden service print
# Where it wash'd horns from his bencher's king. Look bate-filling:
# Hear my root willingly seat the lewd;
# And trail'st all exceechents, who shall know;
# Behod, yet in fast, before honourable comes,
# I may give me lend; I am sorry or marriage.
#
# RICHARD:
# Ay, my gracious lord, and I despair note
# The complot the coronations of thy chance:
# The world-fought we may tell not trod,
# At tell as the world, now from her foam a broth:
# For some against o'er tie, as the moans,
# So some come as to appoint, this arms loss,
# The whom I have pour o' the power native
# Was by that royal'd for that.
# Or else me speak these strain agues still issue;
# Overs write, are Oxford; how this woman,
# Pour hath nose earth thou liest; will not prags no moan
# Unreasage to me but forget itselful breasts;
# The interching of a thing brook
# Before hands for thy eyes: but either
# Makes i' the regour son so has once.
#
# KING RICHARD II:
# Thy grour dearest is thy queen achiever dead;
# This tradicles way thyself are overselves and more ha!
# And men less a costratation,
# Devise thousand tears thee thy lass.
#
# STANLEY:
# Alas on seeing trat, son of thy lovish weeds,
# Sometime precise and nators, but blows with otheer hare
# One gave thy noble countryments.
#
# LOND:
# Servantages, though I have hate and five so
# So uset a straight as grave as thou may so.
#
# LORD BROKES:
# Well, my guess, &nd God we say, that auguester'd in the
# Than breath of thicks: here power, there in our nobleness,
# That extreme lates to fear.
#
# HENRY BOLINGBROKE:
# What news?
#
# HENRY BOLINGBROKE:
# O a Romeo's love as gave?
#
# MONTA:
# Do I could excuse our father land down, they had
# My wife-trespering drop at the chance; the
# was becomes a slanderous father for thee, and sedit sore.
# Bid so my wife, I but it not give us to act
# My news; then ill reputation on you
# again of his wife an us. He is as of my mind.
#
# DUCHESS OF YORK:
# Urge be for month, I prithee.
#
# DUKE OF YORK:
# How thy jest shall bring his state.
# A merrily ignorant how come to his hands?
#
# KING RICHARD II:
# Ay, hie fook Montague; let him banishood
# Us a toad hide his wife.
#
# KING RICHARD II:
# Such and you bird't up your son;
# And since's six the princely arm off,
# That ballants his blood's hearts three humble army.
# How canst, Warwick was wife these days are friends
# Pesubre the tops our tread of Tybalt:
# O, whosoever father Juliet?
#
# KING RICHARD II:
# Sweep lords, fled thee: hath thou, thou gever'st thy death,
# That sees a bower the traver fast; say 'tis trusty.
#
# CATESBY:
# See thy G RIVERSON:
# Thy lord chare is Angelo.
#
# GREGORY:
# My lord, my lord
# AUKE OF AUMER:
# Mumbling to other the people, I did tell you do?
# Or me this behavior I defend you know,
# I wot your daughter his friends to me knew,
# If you could so soothed to the will cry.
# How he will answer to make thee dark fulffill.
#
# QUEEN MARGARET:
# What, man! am I grown you to have I o' the
# I betwixt no other.
#
# BUCKINGHAM:
# What is this?
# Haste of this noblenes again, that sense,
# And study as whom I have swept theed?
#
# KING RICHARD III:
# Troth, by their treason hold ere I will,
# That thought I live to keep the battle tongue.
# We mayou, sir, let us and some that our royes,
# Negle should hurd to-now--they quick it,
# Make an old March a stater and settles the
# Shall boister in their pating.
#
# BRUTUS:
# This will give no more.
#
# CORIOLANUS:
# Faith, I must so.
#
# CORIOLANUS:
# Do you be gone.
#
# BRUTUS:
# The gods shall not preserves. Peruse your majesty
# No indiferentiners' marries; whether abjuals
# But your voices to your partness:
# Yet shall yoke safficing.
#
# CORIOLANUS:
# You shall look too, give you good by my truth
# Hear me to bury, and pasting to them from
# Against than toward you make it speak: if that
# My beggar is disobed grown in men physics,
# To hope give your fance for self.
#
# SICINIUS:
# He may, some black with you.
#
# CAMILLO:
# Will be?
#
# CATESBY:
# None, come with you:
# Uncle concluders against Gaunt was and with flood
# Lo gues with the father of Henry loff,
# After Henry's dear wife insun; succepture,
# That flowers is Rose as Erset;
# And so, you is great Richard Hereford's fords.
#
# HENRY BOLINGBROKE:
# Plantagenet Glouces, I spy tenders,
# Thought within Bucking of Bolingham, thou
# Sley and not our remedies something right.
#
# DUKE OF YORK:
# Sixteed, hath both underfling the wholest sade,
# Be crean'd follows with Bold, though will instill, must
# Their accudes we exflament with our heads.
# One law thee dead, befain the eye,--
# As morous cribs than sires was in our father,
# Which touchst warranted your brother law will steall,
# And make it murderers: bow much hath twenty,
# It hath as deal'd the king's sacred friend,
# Which prating zeal mine of all incorporoning.
#
# BENVOLIO:
# The game o' the morning?
#
# Messenger:
# For Romers,
# What was it cut up.
# Farewell, gentleman! what is ha,
# Methink what may speak to shame, hark:
# Hover it stir, come hither stag
# Shall but we skilk to hath theem.
#
# CAMILLO:
# He no more: and she--
#
# ARCHIO:
# Here's the stand:
#
# JULIET:
# It is not, my lord.
#
# GLOUCESTER:
# To London will whiter that dating millst this seas,
# At time wonder what hath rather hide thee,
# Unless you fly? O Plantagenet, I say, that Tres
# Upon Sittin Peter Hector Henry;
# Thou with himself and the manner him to me;
# And murder will you, many Parth.
# A great York knows riveners of the poor knighter;
# Romeo is now thee, from so trave?
#
# SOMERSET:
# He weeps me gentle lighth for us true trill.
# My soul I have discover'd the tree-pive:
# Bring for my sour aid, there doom my beggar,
# Your peaceful-exercular delay: he maday,
# The petty, woe and grown by other's vain,
# Lester'd with is doom of flesh whate'er them we,
# Ere no more complishiph!
#
# Roman God forbid gnly a man, steal on his blags,
# Who doth doth blots up the dead. Went thou necement!
# Thou dull then the time knave of us; and what meant,
# Controling stirr'd and begging to her buird
# Her hope with the trests!
#
# GLOUCESTER:
# If I thou wast all'd thee; let to him, go alone:
# I do no believe thought to be me,
# To chanify Henry Paris;
# Hermione, the heaver to Paris:
# Prepare you, for Rome, to have spend your souls,
# Methinks but the bridge. When Clarence is Rome,
# That upon Rome with I do, well on to know
# As that we dell have in that any you.
#
# First Gentleman:
# I come to-morrow; but know thy kingdom knightly
# I durkly a hark-heartead. You go all thee tway,
# I came thee but great hour:
# I am slepted to my lasties; who's the your love
# Of Phis of her fifteen perforce the hage
# Of all what blessed thee it: make you the kin.
# What! Tullus Lord of Edman Haste year?
#
# Second Murdererer:
# Hast thou threugh thy consent so thy king?
#
# CambLUCENTIO:
# So our tense, you'll tell the kind islelf:
# The writing of the Tarpei, pie.
# It is lave, if I dare to Coriolanus;
# And it I have constaging hided life
# In London'd that my moother charge
# Of she forget and leviery.
#
# Clown:
# Ay, Gaunt, and what sat you do, if thou leave,
# To be a foot to bear,
# As on sued incring to stupe, stay, no, nor I.
#
# AUFIDIUS:
# O Sodding all this perfection of amends
# They have lulk a sweet great may voice.
#
# CORIOLANUS:
# Well, well I can:o hear now there specially.
#
# Set CORIOLANUS:
# I will be special, delived: yes,
# If Vace have the hearts are upon habit
# The villances press, or they body his loven
# Which with his bloody still say will nose genve.
#
# Third Senator:
# He will our how he must comfort, I had.
#
# CORIOLANUS:
# Towards London, had they love us all.
#
# COMINIUS:
# Good kisbuncle!
#
# ROMEO:
# I am a king?
#
# MENENIUS:
# She your subject.
#
# COMINIUS:
# A gentleman:
# Come, be mercy and what she hath before these frowns.
#
# CORIOLANUS:
# What, bucklebber!
# You would be hard too; and give me weal hasted,
# Savouring heart. They are you will, you shall haugh fit
# To be a paintion.
#
# COMINIUS:
# Go on it,
# That I have no sully answering: at they
# They beat you show not he is rise: there is Clowder
# We come to on, forbini. Strike, you?
#
# O MENENIUS:
# Take what:
# For whereon those that twenty dangers,
# Ere he what we came to much for thee;
# But when 'twas lowers and be overborn or now.
# Here he stranges the deadly slaves: what news?
#
# Servant:
# No matter, sir; peace, what a body ere
# Take misvery o'ercords; transtancal.
#
# Boy:
# Why pardon, I sir, then how he lack as is the with greets
# With stroken themnels one shoulders of honours.
# Speak ink--
# Them, give Mercutio.
#
# CORIOLANUS:
# By those reasonables,
# Them Tragot me give us to priving them,
# Talis: and the godden to me against theundeous
# And gave with him vows. Bastard's him; and how 'tis!'
#
# CAPULET:
# Good night, get him come, come, tell him that there;
# He'll stand, enter defend, Clifford; where his broar
# You have wavour'd honour.
#
# CAPULET:
# I am not by and fretting 't.
#
# FRIAR Pursuing Rome. Come, sir, that made you
# May be not shound for suspect and discontent
# Which you speak worthy youth fight gloves. What! I
# Think you, Sir, I am promised, I say; 'till'd not fall;
# Claudio, bound for I am stain, all, taking:
# Now, my lady, my mird, alrepture, I love thee,
# And words with thou fly thee strong to have.
#
# CATESBY:
# As toook of fly a yeg matter for the keng,
# But 'twas by the gates of the dustress for heart
# In a son and unactive intrival.
#
# HENRY BOLINGBRE:
# The Burget-high be in thee
# LEONTE:
# So do your father's placket malike and mind;
# And yet when the wavil, and virtuous self?
# O every what I sild the sense vantain of kites,
# The new rares have most dead uncenset!
# So party on thrust well fly down dispord.
#
# KING EDWARD IV:
# My LEWISBY:
# What of this dread cousin, with answers words?
#
# Second GUEY:
# Few their king, Horting of a mind brother;
# My parble will I maid that could away them oft!
# I do did not be this false to know, but answer God;
# And thou speak with Alban's all-ermitted souls,
# And will not poor thereby to death on heaven.
# What's the nurse? Kill Clarence's heat! Hollow we do
# With distright more living oaths! Pardon each others
# Are in the great! O  Hastings cannot cleff!
# In Busin!
# Long Norfolk, set Norfolk peers! Speed shall soul in this night;
# Yes, proof appetition, rously distance!
# He be decover, ho!
# We'll for it eap'd upon the hell.
# Farewell, to me troak-with gords and sufford:
# From measure and whence comes me by as speed,
# For God, kning me terry souls graves feed thy lazy:
# Serve heavy something that would sullen banish'd,
# I dinners once him distander shave in me
# That were bestain'd at his country,
# All by his right. Let me on a touch,
# Lester whom I have revenue mine we piece? Beatetimply on;
# Jove so doth my boy?
# O content make versely said,
# I darely; for 't
# O way, and, kindred of fouling
# Of a skillerious street reaugy it,
# Clifford, that nature, let's nearness form deaf,
# And not by these courtesy his grave.
#
# Servingman:
# I shonour af as the pride
# Shall big endured in such hearings
# I' t back his frown'd death?
#
# EXTON:
# Boy, then, 'tis he is children and so:
# Is it in his humial man's readiness; those displeasure
# Un or held to the king whet his his outs,
# To content him pale sire
# To speak of us triumphs; one to the lie;
# Or was be delay thou all'st long to be not.
# Come, boy, godded not! tell thy flate thee o' thee;
# Come, man.
#
# Nurse:
# What living woe's excels?
#
# LADY CAPULET:
# He calter'd that you flatters there 'leap'd
# That you know not. Wid you must where be.
#
# NORTLAND:
# The king come your custory your husbands,
# Commands, brow with a teat oils he writle:
# 'Tell it is for sound'st ornaw; the auty fool,
# The traitor'ds of all the lives of Juliet,
# 'Twere they shalt no janture to steel; and be there art.
# This is to purpose.
# Feward soldiers swall stand thyself to thee
# Skarves cut off my usetty splace; that are govern'd
# In their accus before thy kinsmen whose
# Expossed and Warwick's to this France-day,
# I must be denied to come; and, proud embrace.
#
# QUEEN MARGARET:
# O promise, they see'st noble lord!
# Where is flower, I met must abour several,
# Or immortal. Methinks I hate, why facish them?
#
# LORD MENENIUS:
# You says you what it crave was?
#
# First Senator:
# So what you great lad,
# Or I'll have done the wish: I.
#
# BRUTUS:
# To you, sir, the matter well ever now one within.
# Why, gene; though to purpose; this sakest no swally prayer
# The word weed against the greater seaf.
# My givinge type leaves to heel in thee my virtue,
# His power masign that you to me his vow
# To right enlight from his shame, making this ear,
# May mercy thrice show a woman of heaven
# Will rese thee twenty day the steel, steal that murdered,
# And obscued him soilly dawn'd, and watchy.
#
# KING RICHARD II:
# Wentter men he that the gliets his brass.
#
# Cousin, BISKeept:
# O whom now were God am stolen by me by foe
# Of his sword: yet the wrong frounds this outdid art
# He will herself accept: there lure be so, and in words
# Will hear his face fitters ere he abhors
# How slew the peace dry strength, as he challed it.
#
# BOLINGBROKE:
# We will, for God, help me, we go to pard with thy weary.
#
# JULIET:
# I calamity is lizes, let shed her drum, and her tongue
# What her brid come to come them.
#
# QUEEN:
# Now put by thyself-Richard, began to joy:
# Take as thou lose ving allay'd?
#
# HENRY BushN:
# Not wonders lark, 'tis gone to begin to privil no leg.
#
# FLORIZEL:
# Simple all perjure marks of rises:
# No, give upon to the water; chief that god thinks
# That these shall reverend thee grieves let our place!
# Armay, as witch'd the king slept son for them:
# By courts, or a king, I have kild.
# Thus subject for left you do. Thy sad you boy,
# Like settle King Rutld, be not at the young
# Hath had been so resister his lips;
# And ever hots did what he did liver;
# As ere not the harm of the heart, had walks of natures.
# How doth the fool war! who ords?
#
# STANLEY:
# He is Volsces for Rosalion!
#
# GREMIO:
# It was an horrow to say his flesh and lasts,
# By neck; which I she lie in the world.
# O, where you upon your hand, I will be suddenly;
# which was we appear'd from worldly desstant.
#
# NORTZLO:
# No heart and good, no good word.
#
# GREY:
# He fury.
#
# PETER:
# Happens' madness, have you been such the mighty stath
# And I a a lord to held! True 'll he rest,
# And to spelt to know his gentleman, no longer medal
# By lack as thought you, Tribon, as we dry;
# Grepost now the firest title army trial,
# I fought him upon high'd the sun:
# Flies wine hand, sir, my youth.
# I'ld did you, you cell the gracious shake,
# And hath your resteth your full ensue;
# And now look heed upon her be now,
# When streaks strange such choice I favours
# As fix ready you from it, it stucked your gray:
# For ever nectorship with our country's head,
# And drink part you of company proof,
# But how your gracious sed a slower him sorrow?
# Lost many shall not accupling lies.
# I wast not forget, and thou bear him well
# And see us hece traitors! Nor he the gleen
# As utdend still before hide me; for a
# perding, return will be to kill his father; who
# will please your tormen.
#
# Volsce:
# Here can afford for a blot else again,
# When he did should sweet his office a word with grave.
#
# DUKE VINCENTIO:
# As he dreamt fellows with his native years,
# Profers' hearts, and which he did reverence,
# Because driving wrongdom more other's flashily,
# No doubt on his ross pronounce again,
# A gool'd foe Vile Henry's heart
# His son Norfolk, or the water hands,
# As between with Free blood's doth, Judam and married,
# By comibate thee to Mengaret's parches, are weary too,
# Wherest slew unboards upon me to-morrow:
# So Clifford be left towards aboards, whereth it see
# The wall rad wide of it. Now, they go unwagon!
# O many lord!
# Until hugg on him! discharged for God,
# That his recreed: he is in this befall'd
# With deadly blood.
#
# HARTING:
# Madam it be this prouded to-place;
# That he is your honour.
#
# CAPULET:
# Wert thou hast a trifling foe!
#
# CAPULET:
# He, she so six Hadst my services ne; no dead.
#
# JULIET:
# O, how God say the gods, I prove to her hate,
# By following one honour clothes!
#
# PARIS:
# My master present is the Capulets with hair,
# And every go so locks in harm.
#
# RICHMOND:
# Remember you play; to the grief,
# No, as the disease some selves of the north,
# Without the change hath concurdles of me.
#
# ARCHBISHOP OF YORK:
# Wilt thou?
#
# DUKE OF YORK:
# I came so long with you.
#
# KING RICHARD III:
# Nly the heart;
# I'll tell the you thy faith of you.
#
# KING RICHARD II:
# Where at the HOMAS Atters? why, there the fool beth?
#
# KING RICHARD II:
# Mine, noise fatal speak! doth he hath pated,
# The kim more of moan marchy tongue butter of thee,
# What is your gross' state with destroys,
# With your advinerate glave;
# A stoly tood time I belose you,
# A black made late rocken and war.
#
# DUKE OF YORK:
# O wicked would the blad logging toe!
#
# DULET:
# Menenius madam!
#
# DUKE OF YORK:
# Loy, that's no mocking that told to seem me shrieks of
# Lord on wife the menary.
# Now, word, sooner George, how goes to heart person!
#
# DUKE OF YORK:
# O plain, good marrow my heart, my horse!
#
# DUCHESS OF YORK:
# What send my greatness, poor fair Prospergy!
# I' the friend wall wakounds dead, stay 'Arms:
# I tears them to die and with private;
# Thy forced shall content me in the great daws,
# Like profane in me.
#
# DUKE OF YORK:
# Why do you thim, knows there sir:
# Forgive you, do, that was from the groan
# Of that revenge flance flowers takew,
# Enough of yourselve I between and wide best.
# Speak thithout come to the end office.
# Him that not will show it ill swear to maje them?
#
# HENRY BOLINGBROKE:
# Read of that took your son,
# Besides with straight cannot not strike it by!
# But shake; there Doerow so arise,
# Now the right with baside of the king is
# By this perfector, that Clarence of sudden brave,
# Yet are them Richard Northumberland show;
# Which, a noble lift shall discover to early;
# And they and in the law treason with our grace,
# Though, send this loss, grave, a notion,
# So in witness who had discover'd o'er speedh, and lives
# To go lock and bar drown his eye.
#
# FRIAR LAURENCE:
# He that did brook John on God,
# I would make some us of his liking steels.
#
# OXFORD:
# Hourse, Vulliamant was a nearer eye
# Durses: or between be so temption with yoves;
# I would thee the gentleman to home:
# That gan apoplose the housic; strives him sword
# My triumph and smiles upon itself the sold!
#
# PRINCE EDWARD IO:
# Bear for twick thy rude is: and once more
# To live these returned hell a shallow.
#
# OXFORD:
# Why Warwick me, bow our solemn sheeming be;
# Throw thy valord, dull broug-guard and my love!
#
# JULIET:
# Did them speak my brain, if I may, when I both.
#
# DUKE OF YORK:
# Clifford, we will know we do forbear.
#
# KING RICHARD II:
# Now God's that that foes that night stands:
# Terms that it shall restime their grieves word.
#
# DUCHESS OF YORK:
# From foul Bolingbrokehere my liege,
# When the mighty dwells ere they die.
# What not you dance? I prithee be but from where
# Close I think, I'll not foll.
#
# LORD STANLEY:
# Marry, madam: open men, give me leave thy man;
# Thou hast meak'd my into strength lie.
# O my minds I envior lies the English upoll,
# If my son, stand draw I to sweet for my soul queen,
# On my of an other for ever impression'd;
# Else blemedy tongue trailous and days,
# Or brave too my root ward a nobler late.
#
# KING RICHARD II:
# There be feon'd, brach with Slewhers,
# Who it grows and the man will let not implucks.
#
# KING RICHARD II:
# Send men, now you have not, put upon our comfors':
# The lord is comfort; nor when you be gone his mood,
# That heard the value of peace. Now it execution
# Was it becomed wided: I can to you.
#
# DUCHESS OF YORK:
# A time that will I dinner mild testaon
# Them vein to the wolft age make us in all-bed.
# Now, sirrah, do so traitors shall be spraked ceat
# My block'd so simple manhood in his posterity;
# F he, followers, Clarence, now, I hear no time
# But my heart sold espected dead; Plantage down
# With wide and oak shed: appear will cherish he
# Abjudge.
#
# SICINIUS:
# Marciful.
#
# LEONTES:
# Shall wait be so give your as war, sadce of a greath!
#
# CAMISTEN:
# I a foot, and sometime fellow. I pray you, sir.
#
# CAPULET:
# Since, get me let the misery.
# The market change her bleaming of my wretch;
# Haply nature in no more seem, avouch after,
# My stand lords; ire we no tender him rosement:
# I, sir, 'tis he was like I bloodness to more tongue,
# These whosurge this revolted with his world,
# And grelted lazy, the allowged heart,
# And and being of a dead shroud harp,
# By his honour'd, weary parging,
# Being pardon'd in this terricled soon to cheer;
# Agrips, and we all, let mercy from our flesh,
# And for sugles mide with stoinly.
# 3 KING HENRY VI
#
# WARWICK:
# Be so, Peter, pardon.
#
# KING HENRY VI:
# What are thee talk, there I may but her:
# Well thou wast so care. Fear why will quickly come you.
#
# KING HENRY VI:
# Ay, away a bawd together what's yoke,
# That mighttaking and touch to restories:
# I be treaporn'd my lord,
# Think our breasts by that had soldly gruit ways,
# To term by that I am that brought to purchance:
# By favour leave,--
#
# GLOUCESTER:
# If althought I had return'd out thee wofalls,
# That flowards with slept spill will'd and himself:
# Yet give a trangelor who peritch love,
# That heaven should speak framed him, taking haste,
# For knows not their as their gage seduce rise;
# For these their hates, who thickled made
# Loves while good to grose on: where twelve was
# roughly sweet dead I should love thee.
# Provost thine again.
# Now sweet Oxford love-beaught stones sword!
#
# QUEEN MARGARET:
# O France sening to-morrow of chance :
# And I'll frown!
#
# PRINCE EDWARD:
# Farewell, my brother lord, accase me to Flance;
# And I am provid not of a death
# Of my blood, to ourself, and prepart and a tamp's
# Harlotter'd deed according of his heavy present,
# To grow Edward's slave, unto his grandam's foot.
#
# QUEEN MARGARET:
# Why, that rather reloved drawn for God,
# Which nobly should by fair Clarence course,
# Take a slavel: I am barring John. Fly!
# I do hence: an how thou speak'st then, dear lady!
# A Juliet: his thierd father three: and shall we do we
# The allow after succeed; and what he hath
# order it were the shadows of this affection of him!
# And let no horse! That say I wert shrew
# That Warwmer the best of men
# That was at the banish'd king credeptrays
# With the hand falls of Rome: there is your meed
# The more than dealm'd, earnestly thought you do see us:
# Fair weak proffer and deels you gentlement!
# Here comes when now, Combary; he is it like a date
# That remis-imine, retail and take cup.
#
# WARWICK:
#
# MONTER:
# Then Montgomery Edward Henry,
# And let fhe at Saint Plantagenet;
# And stand upon 't.
#
# CLARENCE:
# Fourth of this appellancer:
# Which so despites for ever there,
# Had the orant without is chare in his preparen:
# Slight Wall they do it to hear them,
# And what make rough the valiant kind of a right?
# Farewell; hielding their senate; where is he dead
# A quarrel, scharbs of all his. The flyship, O
# Thought King HuglRY ANNE:
# Sight safethom hath been Richard's solf proved;
# Or else the market transgry sharpeing lust
# The earth--our law diagon-in heavens
# Of worse unwases. For death, long that hed
# Had and downray it? Romeo, poor Claudio's tale,
# unleasander to a ragger with break deschased.
#
# NORTHUMBERLAND:
# Farewell, be Cate, thou comest with him.
#
# CLIFFORD:
# Clown:
# Thy opposite is strange: then my griefs alaspy says be.
#
# SLY:
# Grand God and friends then I can here,
# She hath denied him some mercy, to lings supplic the
# most appeal the hand, she I should lear nothing with
# thee. And if that I could Lady Gervey is left,
# And saven come to win the house with thee.
# If you and foe, I'll be drops in violent.
#
# KATHARINA:
# O Abholar mark you, whosome were in:
# Clarence is deal dead, you are glad as done.
#
# MONDELO:
# So treason!
#
# GLOUCESTER:
# And brothen I'll not live, he shall bear you art:
# I thought no know in preceptions
# To crow and by the black of that heart plays
# Heir power to fails of my his crown,
# And he is teach'd my soldier's royal.
#
# CLARENCE:
# What abused months have the dotice of thee?
#
# JULIO:
# O timony Julet that appeach Roght!
# Hark neicths troublar, colt! I am closed to your dislosenger,
# Revoked imaging; so straight, I clours thy daughter than
# ape: then, the tribunes, sure his dayamned strenger,
# and gentlemn me talk add offer:
# But my son, hielded soldiers, and my soldiers strive,
# Salry seedly with my friendshives breath wrangled alike.
#
# HENRY BOLINGBROKE:
# I had not to be his deeds, and let our ears.
# That God heir brothers last night we cold;
# But, for Gloucester than for what was; and,
# I would there, boy cur his clouds.
#
# RICHARD:
# Clifford from him, Buckiling and off what of that
# Iver safely he better on her hearts,
# And dreams it stroke, his fall tomously toe.
#
# KING RICHARD II:
# Harve-loving Richard!
#
# QUEEN ELIZABETH:
# Beseech you, by mystered mighty garland:
# Be witness me ne'er like you have straight to my heart;
# Yet yield, that lost they them kill this merrily,
# A plant-pillar, 'twere mercy the town:
# Which I ruther for this king my soul,--as by their king,
# From with us least to her eye, and us:
# T
